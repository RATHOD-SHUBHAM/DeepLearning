# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

# %%
image = cv2.imread('/content/drive/MyDrive/Colab Notebooks/Section 4 - Computer Vision Basics/Copy of Self_Driving_Car.jpg')

cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=640x426 at 0x7F2F0B4E7890>

# %%
# convert to grey 
gray_img = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_img)
# Out:
# <PIL.Image.Image image mode=L size=640x426 at 0x7F2F0B493150>

# %% [markdown]
# # sharpening Kernel

# %%
# Sharpening Kernel #1
#Sharp_Kernel = np.array([[0,-1,0], 
#                        [-1,5,-1], 
#                        [0,-1,0]])

# Sharpening Kernel #2
Sharp_Kernel = np.array([[-1,-1,-1], 
                         [-1,9,-1], 
                         [-1,-1,-1]])


# use filter  inorder to activate the kernel
Sharpened_Image = cv2.filter2D(gray_img, -1, Sharp_Kernel)
cv2_imshow(Sharpened_Image)
# Out:
# <PIL.Image.Image image mode=L size=640x426 at 0x7F2F09B9EE90>

# %% [markdown]
# # Blurring Kernal

# %%
# Blurring Kernel 
Blurr_Kernel = np.ones((3,3))
Blurred_Image = cv2.filter2D(gray_img, -1, Blurr_Kernel)
cv2_imshow(Blurred_Image)
# Out:
# <PIL.Image.Image image mode=L size=640x426 at 0x7F2F09BF3810>

# %% [markdown]
# # Perform normalization

# %%
Blurr_Kernel = np.ones((3,3)) * 1/9 # 1/9 is normalize
Blurr_Kernel

Blurred_Image = cv2.filter2D(gray_img, -1, Blurr_Kernel)
cv2_imshow(Blurred_Image)
# Out:
# <PIL.Image.Image image mode=L size=640x426 at 0x7F2F09B9E8D0>

# %% [markdown]
# # Stronger kernal

# %%
Blurr_Kernel = np.ones((8,8)) * 1/64
Blurred_Image = cv2.filter2D(gray_img, -1, Blurr_Kernel)
cv2_imshow(Blurred_Image)
# Out:
# <PIL.Image.Image image mode=L size=640x426 at 0x7F2F09B958D0>
