# %% [markdown]
# # 3 channel
# 1. Hue
# 2. Saturation
# 3. Value

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

# %%
image = cv2.imread('/content/drive/MyDrive/Colab Notebooks/Section 4 - Computer Vision Basics/Copy of Self_Driving_Car.jpg')

# %% [markdown]
# # I read the image using cv2 - displayed using cv2

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=640x426 at 0x7FA3E69DBE10>

# %% [markdown]
# # I read the image using cv2 - displayed using matplotlib

# %%
plt.imshow(image)

# %% [markdown]
# # The difference is because RGB(matplotlib) and BRG(cv2) are reversed in cv2 and matplotlib

# %% [markdown]
# # Converting to grey color -  BGR2GRAY

# %%
gray_img = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_img)
# Out:
# <PIL.Image.Image image mode=L size=640x426 at 0x7FA3E4843950>

# %% [markdown]
# # Color to HSV- BGR to HSV

# %%
hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
cv2_imshow( hsv_image)
# Out:
# <PIL.Image.Image image mode=RGB size=640x426 at 0x7FA3E4843FD0>

# %% [markdown]
# # Displaying different channel

# %%
# channel zero is Hue
plt.imshow(hsv_image[:, :, 0])
plt.title('Hue channel')
# Out:
# Text(0.5, 1.0, 'Hue channel')

# %%
# channel 1 is saturation
plt.imshow(hsv_image[:, :, 1])
plt.title('Saturation channel')
# Out:
# Text(0.5, 1.0, 'Saturation channel')

# %%
# channel 3 is value
plt.imshow(hsv_image[:, : , 2])
plt.title("Value channel")
# Out:
# Text(0.5, 1.0, 'Value channel')
