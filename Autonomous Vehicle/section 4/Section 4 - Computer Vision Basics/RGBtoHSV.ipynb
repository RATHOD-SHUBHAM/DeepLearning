# %% [markdown]
# # Image Manipulation
# 1. convert from RGB to HSV.
# 2. Convert to Gray.
# 3. Split the 3 different layer into individual ones.
# 4. Merge the different layers.

# %% [markdown]
# # Step 1 : Import all the libraries

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %% [markdown]
# # Step 2 : Read and display image using cv2

# %%
imageCar = cv2.imread("/content/drive/MyDrive/Colab Notebooks/Section 4 - Computer Vision Basics/Copy of Self_Driving_Car.jpg")

# %%
imageCar.shape
# Out:
# (426, 640, 3)

# %%
print("Height = ",int(imageCar.shape[0]), 'pixels')
print("Width = ", int(imageCar.shape[1]), 'pixels')
print("Dimension = ",int(imageCar.shape[2]))
# Out:
# Height =  426 pixels
# Width =  640 pixels
# Dimension =  3

# %% [markdown]
# # step 3:  Display the image on screen and close the window

# %%
# cv2.imshow("Self Driving Car",imageCar)
# cv2.waitKey()
# cv2.destroyAllWindows()
