# %% [markdown]
# ## CODE TO PERFORM PERSPECTIVE TRANSFORM

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import matplotlib.image as mpimg
from matplotlib import pyplot as plt
# %matplotlib inline

image = cv2.imread('/content/drive/MyDrive/Colab Notebooks/section 5 - Computer Vision/Speed_Sign_View_2.jpg')
# cv2.imshow('Original Image', image)
cv2_imshow(image)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=800x600 at 0x7F2DA0423650>

# %%
image = mpimg.imread('/content/drive/MyDrive/Colab Notebooks/section 5 - Computer Vision/Speed_Sign_View_2.jpg')
plt.imshow(image)

# %%
height, width = image.shape[:2]

# %%
height
# Out:
# 600

# %%
width
# Out:
# 800

# %%
# First entry: top-left,
# Second entry: top-right
# Third: bottom-right
# Fourth: bottom-left

# Cordinates of the 4 corners of the original image
Source_points = np.float32([[200,60], [450,150], [520, 500], [170,470] ]) # [x,y]

# Cordinates of the 4 corners of the desired output
Destination_points = np.float32([[0,0], [width,0], [width,height], [0,height]])

# %%
# Use the two sets of four points to compute 
# the Perspective Transformation matrix, M    
M = cv2.getPerspectiveTransform(Source_points, Destination_points)
 
warped = cv2.warpPerspective(image, M, (width, height))
 
# cv2.imshow('warped Image', warped)
cv2_imshow(warped)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=800x600 at 0x7F2D9FEA3910>
